# %% [markdown]
# #The goal is to classify the patients based on their HIV reverse transcriptase and protease sequences

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# Import reverse transcriptase after embedding

# %%
import pandas as pd

# Load dataset
df_RT = pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/ embedding_results_RT.csv')
df_RT

# %%
RT = df_RT.transpose()
RT.shape
# Out:
# (920, 506880)

# %%
df_ORIGINAL= pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/HIV training data.csv')

# %%
labels = df_ORIGINAL['Resp']

# %% [markdown]
# PCA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Example data
# Assuming 'RT' is your original data array
X = RT

# Example labels for each data point
# Assuming 'df1' is your DataFrame that contains 'Resp' column
#labels = df1['Resp']

# Perform PCA with 100 components
pca = PCA(n_components=100)
X_pca = pca.fit_transform(X)
columns = [f"PC{i+1}" for i in range(100)]
xdata = pd.DataFrame(X_pca, columns=columns)

# Add labels to the DataFrame
xdata["Label"] = labels

# Save the PCA-transformed DataFrame to a CSV file
xdata.to_csv("pca_transformed_RT.csv", index=False)

# %%
import pandas as pd
PCA_RT = pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/pca_transformed_RT.csv')
PCA_RT
# Out:
#            PC1        PC2        PC3        PC4        PC5        PC6  \
# 0    17.736394 -17.521798  39.547496  12.606677   2.408114  -1.432470
# 1   -19.003402 -18.705583  -9.237573   3.306062   9.965538  19.164463
# 2   -13.425743 -20.558149 -10.861395  -2.127442  -7.059768   0.819381
# 3    97.142233  22.497278  -9.389025  12.269651  -2.138742  -2.830694
# 4   -11.382036 -19.302507 -11.481323  -5.408969   1.291443  20.698428
# ..         ...        ...        ...        ...        ...        ...
# 915  -9.261302 -21.179137  -7.879062  -6.166147 -13.470064  -7.352158
# 916 -11.974485 -20.450403  -6.598146  10.862635   8.157497  11.880031
# 917   5.530160 -20.984534  26.573500  -1.655916   6.451876  -1.857636
# 918 -12.104367 -20.204940  -3.909175  22.460113   3.453386   0.399040
# 919 -23.675434  18.546116  -3.310142  -8.578271  26.209589  -6.133160
#
#            PC7        PC8       PC9       PC10  ...      PC92      PC93  \
# ...

# %% [markdown]
# Import protease after embedding

# %%
df_PR = pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/embedding_results_PR.csv')

# %%
PR = df_PR.transpose()
PR.shape

# %% [markdown]
# PCA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Example data
# Assuming 'PR' is your original data array
X = PR

# Example labels for each data point
# Assuming 'df1' is your DataFrame that contains 'Resp' column
#labels = df1['Resp']

# Perform PCA with 100 components
pca = PCA(n_components=100)
X_pca = pca.fit_transform(X)
columns = [f"PC{i+1}" for i in range(100)]
xdata = pd.DataFrame(X_pca, columns=columns)

# Add labels to the DataFrame
xdata["Label"] = labels

# Save the PCA-transformed DataFrame to a CSV file
xdata.to_csv("pca_transformed_PR.csv", index=False)

# %%
import pandas as pd
PCA_PR = pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/pca_transformed_PR.csv')
PCA_PR
# Out:
#            PC1        PC2        PC3       PC4        PC5        PC6  \
# 0    -1.885705  -0.651117  11.843484  4.869802  -1.839872  -1.211086
# 1     8.164608 -11.079589   6.101052  1.325754   1.939282  -2.708731
# 2    -8.200550   7.256495  -5.723636  3.398085  -4.638080   4.988093
# 3    -8.060616   5.178030  -3.000635  5.470617   5.086985   2.029444
# 4    -7.668880   4.791262  -2.451455  0.302582   6.092274  -0.743318
# ..         ...        ...        ...       ...        ...        ...
# 915  59.871827  54.162080   8.097254 -3.236060  12.931489  16.105584
# 916  59.070576  54.637252   8.540747 -3.078992  13.713314  16.550111
# 917  17.881770 -15.291705  -1.319019  5.066728  -1.266534  -2.437618
# 918  51.226825  45.769151   6.619134  1.362370  -1.413785  -7.432728
# 919  56.859693  44.607203   4.913121  0.528673  -3.887909  -7.819411
#
#            PC7        PC8       PC9      PC10  ...      PC92      PC93  \
# ...

# %%
# Select specific columns from df3
df_selected = df_ORIGINAL[['VL-t0', 'CD4-t0', 'Resp']]

df_first_920 = df_selected.iloc[:920]
df_first_920

# %%
PCA_PR=PCA_PR.drop(columns=['Label'])
PCA_RT=PCA_RT.drop(columns=['Label'])

# %%
PCA_PR
# Out:
#            PC1        PC2        PC3       PC4        PC5        PC6  \
# 0    -1.885705  -0.651117  11.843484  4.869802  -1.839872  -1.211086
# 1     8.164608 -11.079589   6.101052  1.325754   1.939282  -2.708731
# 2    -8.200550   7.256495  -5.723636  3.398085  -4.638080   4.988093
# 3    -8.060616   5.178030  -3.000635  5.470617   5.086985   2.029444
# 4    -7.668880   4.791262  -2.451455  0.302582   6.092274  -0.743318
# ..         ...        ...        ...       ...        ...        ...
# 915  59.871827  54.162080   8.097254 -3.236060  12.931489  16.105584
# 916  59.070576  54.637252   8.540747 -3.078992  13.713314  16.550111
# 917  17.881770 -15.291705  -1.319019  5.066728  -1.266534  -2.437618
# 918  51.226825  45.769151   6.619134  1.362370  -1.413785  -7.432728
# 919  56.859693  44.607203   4.913121  0.528673  -3.887909  -7.819411
#
#            PC7        PC8       PC9      PC10  ...      PC91      PC92  \
# ...

# %%
PCA_RT
# Out:
#            PC1        PC2        PC3        PC4        PC5        PC6  \
# 0    17.736394 -17.521798  39.547496  12.606677   2.408114  -1.432470
# 1   -19.003402 -18.705583  -9.237573   3.306062   9.965538  19.164463
# 2   -13.425743 -20.558149 -10.861395  -2.127442  -7.059768   0.819381
# 3    97.142233  22.497278  -9.389025  12.269651  -2.138742  -2.830694
# 4   -11.382036 -19.302507 -11.481323  -5.408969   1.291443  20.698428
# ..         ...        ...        ...        ...        ...        ...
# 915  -9.261302 -21.179137  -7.879062  -6.166147 -13.470064  -7.352158
# 916 -11.974485 -20.450403  -6.598146  10.862635   8.157497  11.880031
# 917   5.530160 -20.984534  26.573500  -1.655916   6.451876  -1.857636
# 918 -12.104367 -20.204940  -3.909175  22.460113   3.453386   0.399040
# 919 -23.675434  18.546116  -3.310142  -8.578271  26.209589  -6.133160
#
#            PC7        PC8       PC9       PC10  ...      PC91      PC92  \
# ...

# %% [markdown]
# Combining the sequence columns together after embedding and PCA

# %%
combined_df = pd.concat([PCA_PR, PCA_RT,df_first_920 ], axis=1, ignore_index=True)
combined_df
# Out:
#            0          1          2         3          4          5    \
# 0    -1.885705  -0.651117  11.843484  4.869802  -1.839872  -1.211086
# 1     8.164608 -11.079589   6.101052  1.325754   1.939282  -2.708731
# 2    -8.200550   7.256495  -5.723636  3.398085  -4.638080   4.988093
# 3    -8.060616   5.178030  -3.000635  5.470617   5.086985   2.029444
# 4    -7.668880   4.791262  -2.451455  0.302582   6.092274  -0.743318
# ..         ...        ...        ...       ...        ...        ...
# 915  59.871827  54.162080   8.097254 -3.236060  12.931489  16.105584
# 916  59.070576  54.637252   8.540747 -3.078992  13.713314  16.550111
# 917  17.881770 -15.291705  -1.319019  5.066728  -1.266534  -2.437618
# 918  51.226825  45.769151   6.619134  1.362370  -1.413785  -7.432728
# 919  56.859693  44.607203   4.913121  0.528673  -3.887909  -7.819411
#
#            6          7         8         9    ...       193       194  \
# ...

# %%
num_columns = combined_df.shape[1]

# Define the new column names for the last three columns
new_column_names = {num_columns-3: "VL-t0", num_columns-2: "CD4-t0", num_columns-1: "Resp"}

# Rename the columns
combined_df.rename(columns=new_column_names, inplace=True)
combined_df
# Out:
#              0          1          2         3          4          5  \
# 0    -1.885705  -0.651117  11.843484  4.869802  -1.839872  -1.211086
# 1     8.164608 -11.079589   6.101052  1.325754   1.939282  -2.708731
# 2    -8.200550   7.256495  -5.723636  3.398085  -4.638080   4.988093
# 3    -8.060616   5.178030  -3.000635  5.470617   5.086985   2.029444
# 4    -7.668880   4.791262  -2.451455  0.302582   6.092274  -0.743318
# ..         ...        ...        ...       ...        ...        ...
# 915  59.871827  54.162080   8.097254 -3.236060  12.931489  16.105584
# 916  59.070576  54.637252   8.540747 -3.078992  13.713314  16.550111
# 917  17.881770 -15.291705  -1.319019  5.066728  -1.266534  -2.437618
# 918  51.226825  45.769151   6.619134  1.362370  -1.413785  -7.432728
# 919  56.859693  44.607203   4.913121  0.528673  -3.887909  -7.819411
#
#              6          7         8         9  ...       193       194  \
# ...

# %%
# Save the modified DataFrame to a CSV file
combined_df.to_csv("PCA+PR+RT+CLINICAL_df.csv", index=False)

# %%
combined_df = pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/PCA+PR+RT+CLINICAL_df.csv')
combined_df
# Out:
#              0          1          2         3          4          5  \
# 0    -1.885705  -0.651117  11.843484  4.869802  -1.839872  -1.211086
# 1     8.164608 -11.079589   6.101052  1.325754   1.939282  -2.708731
# 2    -8.200550   7.256495  -5.723636  3.398085  -4.638080   4.988093
# 3    -8.060616   5.178030  -3.000635  5.470617   5.086985   2.029444
# 4    -7.668880   4.791262  -2.451455  0.302582   6.092274  -0.743318
# ..         ...        ...        ...       ...        ...        ...
# 915  59.871827  54.162080   8.097254 -3.236060  12.931489  16.105584
# 916  59.070576  54.637252   8.540747 -3.078992  13.713314  16.550111
# 917  17.881770 -15.291705  -1.319019  5.066728  -1.266534  -2.437618
# 918  51.226825  45.769151   6.619134  1.362370  -1.413785  -7.432728
# 919  56.859693  44.607203   4.913121  0.528673  -3.887909  -7.819411
#
#              6          7         8         9  ...       193       194  \
# ...

# %% [markdown]
# Import the test data after embedding and PCA.

# %%
test_df= pd.read_csv('/content/drive/MyDrive/ביואינפורמטיקה/שנה ג/מיני פרויקט בביואינפורמטיקה/פרויקט/ProtT5(6)/PCA+PR+RT+CLINICAL_testdf.csv')

# %%
test_df
# Out:
#              0          1          2          3          4         5  \
# 0    28.194540  30.613133  -8.903902  -6.909822 -10.167545  2.397650
# 1    28.181112  30.495437  -9.301290  -6.793345  -9.978700  2.721054
# 2    28.892631  34.472998 -11.236322 -10.063740 -16.697157  0.064883
# 3    29.040341  34.031876 -10.807394  -9.721646 -15.867163  0.181339
# 4    30.029604  36.567224 -13.748907 -10.635796 -18.378621  2.036747
# ..         ...        ...        ...        ...        ...       ...
# 687 -25.607370  -3.378756   0.522709   2.011318  -0.913634  0.609552
# 688 -25.379295  -3.469325   0.193889   5.749671  -2.999725  0.093813
# 689 -25.173595  -3.638840   0.344612   8.873351  -4.797792  1.268094
# 690 -24.081492  -3.183468  -0.138250   1.803994  -0.676240 -0.000018
# 691 -25.156043  -3.573129   0.206287   6.882413  -3.793297  0.558668
#
#             6         7         8         9  ...       193       194  \
# ...

# %% [markdown]
# Split the train and test to x and y

# %%
from sklearn.preprocessing import StandardScaler
combined_df.columns = combined_df.columns.astype(str)
test_df.columns = test_df.columns.astype(str)

x_train=combined_df.drop(['Resp','VL-t0','CD4-t0'], axis=1)
y_train= combined_df['Resp']
X_test = test_df.drop(['Resp','VL-t0','CD4-t0'], axis=1)
y_test= test_df['Resp']
X_test
# Out:
#              0          1          2          3          4         5  \
# 0    28.194540  30.613133  -8.903902  -6.909822 -10.167545  2.397650
# 1    28.181112  30.495437  -9.301290  -6.793345  -9.978700  2.721054
# 2    28.892631  34.472998 -11.236322 -10.063740 -16.697157  0.064883
# 3    29.040341  34.031876 -10.807394  -9.721646 -15.867163  0.181339
# 4    30.029604  36.567224 -13.748907 -10.635796 -18.378621  2.036747
# ..         ...        ...        ...        ...        ...       ...
# 687 -25.607370  -3.378756   0.522709   2.011318  -0.913634  0.609552
# 688 -25.379295  -3.469325   0.193889   5.749671  -2.999725  0.093813
# 689 -25.173595  -3.638840   0.344612   8.873351  -4.797792  1.268094
# 690 -24.081492  -3.183468  -0.138250   1.803994  -0.676240 -0.000018
# 691 -25.156043  -3.573129   0.206287   6.882413  -3.793297  0.558668
#
#             6         7         8         9  ...       190       191  \
# ...

# %%
x_train
# Out:
#              0          1          2         3          4          5  \
# 0    -1.885705  -0.651117  11.843484  4.869802  -1.839872  -1.211086
# 1     8.164608 -11.079589   6.101052  1.325754   1.939282  -2.708731
# 2    -8.200550   7.256495  -5.723636  3.398085  -4.638080   4.988093
# 3    -8.060616   5.178030  -3.000635  5.470617   5.086985   2.029444
# 4    -7.668880   4.791262  -2.451455  0.302582   6.092274  -0.743318
# ..         ...        ...        ...       ...        ...        ...
# 915  59.871827  54.162080   8.097254 -3.236060  12.931489  16.105584
# 916  59.070576  54.637252   8.540747 -3.078992  13.713314  16.550111
# 917  17.881770 -15.291705  -1.319019  5.066728  -1.266534  -2.437618
# 918  51.226825  45.769151   6.619134  1.362370  -1.413785  -7.432728
# 919  56.859693  44.607203   4.913121  0.528673  -3.887909  -7.819411
#
#              6          7         8         9  ...       190       191  \
# ...

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler
combined_df.columns = combined_df.columns.astype(str)
test_df.columns = test_df.columns.astype(str)

scaler = StandardScaler()
scaler.fit(x_train)
X_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(X_test)
#Transfer to a pandas DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=x_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# XGB-model

# %%
x=X_train_scaled
y=y_train

# %%
import numpy as np
import xgboost as xgb
scale_pos_weight = np.sum(y == 0) / np.sum(y== 1)
scale_pos_weight
# Out:
# 3.9197860962566846

# %%
model = xgb.XGBClassifier(scale_pos_weight=scale_pos_weight, use_label_encoder=False, eval_metric='logloss')

# %%
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

rnd, results = [], []

# Iterate 30 times
for _ in range(30):
    # Split to get a validation set
    X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

    # Calculate the scale_pos_weight value for handling imbalanced data
    scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)

    # Initialize the XGBoost classifier with tuned parameters
    model = xgb.XGBClassifier(
        booster='gbtree',
        n_estimators=1000,
        learning_rate=0.001,
        max_depth=3,
        min_child_weight=5,
        gamma=0.1,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=0.01,
        reg_lambda=1,
        objective='binary:logistic',
        scale_pos_weight=scale_pos_weight,
        random_state=42,
        n_jobs=-1,
        eval_metric='logloss',
        early_stopping_rounds=50
    )

    # Train the model with early stopping
    model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=False
    )

    # Predict on the test set
    y_pred = model.predict(X_test_scaled)

    # Evaluate the model
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print("\naccuracy_score:")
    print(accuracy_score(y_test, y_pred))
    results.append(accuracy_score(y_test, y_pred))

    # Generate random predictions for comparison
    random_binary_list = np.random.randint(2, size=len(y_test))
    print("Random accuracy_score:")
    print(accuracy_score(y_test, random_binary_list))
    rnd.append(accuracy_score(y_test, random_binary_list))

    # Calculate ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test_scaled)[:, 1])
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Compute the average of the numbers in the list
print("Average:")
print("results", sum(results) / len(results))
print("rnd", sum(rnd) / len(rnd))
# Out:
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.523121387283237
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.5274566473988439
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.4797687861271676
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.48988439306358383
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.5115606936416185
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.49421965317919075
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# accuracy_score:
# 0.5072254335260116
# Random accuracy_score:
# 0.5101156069364162
# Confusion Matrix:
# [[301  45]
#  [296  50]]
#
# ...

# %% [markdown]
# Neural network model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score
from imblearn.over_sampling import SMOTE
import pandas as pd
import matplotlib.pyplot as plt

# Apply SMOTE to balance the training data
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train_scaled, y_train)

# Build model
model = Sequential([
    Dense(128, activation='tanh', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.5),
    Dense(62, activation='tanh'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # For binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train_res, y_train_res, epochs=20, batch_size=32, validation_split=0.2)

# Evaluate model
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype("int32")
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Classification Report:")
print(classification_report(y_test, y_pred))

# Compute ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Epoch 1/20
# 37/37 [==============================] - 2s 19ms/step - loss: 0.7453 - accuracy: 0.5631 - val_loss: 0.4084 - val_accuracy: 0.8333
# Epoch 2/20
# 37/37 [==============================] - 0s 10ms/step - loss: 0.5900 - accuracy: 0.6817 - val_loss: 0.3108 - val_accuracy: 0.8776
# Epoch 3/20
# 37/37 [==============================] - 0s 12ms/step - loss: 0.5276 - accuracy: 0.7261 - val_loss: 0.2610 - val_accuracy: 0.8946
# Epoch 4/20
# 37/37 [==============================] - 0s 10ms/step - loss: 0.4560 - accuracy: 0.7824 - val_loss: 0.2201 - val_accuracy: 0.9184
# Epoch 5/20
# 37/37 [==============================] - 0s 10ms/step - loss: 0.3965 - accuracy: 0.8259 - val_loss: 0.2078 - val_accuracy: 0.9286
# Epoch 6/20
# 37/37 [==============================] - 0s 8ms/step - loss: 0.3751 - accuracy: 0.8294 - val_loss: 0.2061 - val_accuracy: 0.9354
# Epoch 7/20
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score
from imblearn.over_sampling import SMOTE
import pandas as pd
import matplotlib.pyplot as plt

# Creating an SMOTE object for balancing the data
smote = SMOTE(random_state=42)

# Balancing the training set
X_train_res, y_train_res = smote.fit_resample(X_train_scaled, y_train)

# Defining a Random Forest model and training it on the balanced training set
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_res, y_train_res)

# Predictions on the test set
y_pred = rf_model.predict(X_test_scaled)
y_pred_prob = rf_model.predict_proba(X_test_scaled)[:, 1]  # Probabilities for ROC curve calculation

# Calculating and printing metrics
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Classification Report:")
print(classification_report(y_test, y_pred))

# Calculating ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Displaying the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy: 49.71%
# Confusion Matrix:
# [[339   7]
#  [341   5]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.98      0.66       346
#            1       0.42      0.01      0.03       346
#
#     accuracy                           0.50       692
#    macro avg       0.46      0.50      0.34       692
# weighted avg       0.46      0.50      0.34       692

# %% [markdown]
# Grid search

# %%
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score
from imblearn.over_sampling import SMOTE
import pandas as pd
import matplotlib.pyplot as plt

# Assume X_scaled and y are properly defined

# Splitting the data into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Creating an SMOTE object for balancing the data
smote = SMOTE(random_state=42)

# Balancing the training set
X_train_res, y_train_res = smote.fit_resample(X_train_scaled, y_train)

# Defining the Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# Defining the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [10, 20, 30, None],
    'criterion': ['gini', 'entropy']
}

# Setting up GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, scoring='accuracy')

# Training the model with the parameter grid
grid_search.fit(X_train_res, y_train_res)

# Printing the best parameters found
print(f"Best parameters found: {grid_search.best_params_}")

# Setting up the model with the best parameters and retraining
best_rf_model = grid_search.best_estimator_
best_rf_model.fit(X_train_res, y_train_res)

# Predictions on the test set
y_pred = best_rf_model.predict(X_test_scaled)
y_pred_prob = best_rf_model.predict_proba(X_test_scaled)[:, 1]  # Probabilities for ROC curve calculation

# Calculating and printing metrics
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Classification Report:")
print(classification_report(y_test, y_pred))

# Calculating ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = roc_auc_score(y_test, y_pred_prob)

# Displaying the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# Best parameters found: {'criterion': 'gini', 'max_depth': 30, 'max_features': 'log2', 'n_estimators': 100}
# Accuracy: 50.00%
# Confusion Matrix:
# [[346   0]
#  [346   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       346
#            1       0.00      0.00      0.00       346
#
#     accuracy                           0.50       692
# ...

# %% [markdown]
# The best accuracy is 54% with Neural network model
